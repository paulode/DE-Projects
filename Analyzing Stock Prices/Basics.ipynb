# %% [markdown]
# - https://github.com/dataquestio/solutions/blob/master/Mission177Solutions.ipynb
#
#
# <b> 1 - Load data </b>
#
# - Proposed data structure to hold data:
# - Hash, List, List:
# {'stock':[[day, Value, Value2, Value3],
#           [day, Value, Value2, Value3]
#           ]
# }
#
# This way it's possible to quickly identify the stock using hash table key, then the stock list will have up to 255 items. Each item will have Date and the values for the day. The data is already sorted, so we can use binary search to find a specific day

# %%
import os
import concurrent.futures
import csv


def read_file(file):
   
    # Create key using file name
    key = file[:-4]
    f = open('prices/' + file,'r')
    data = list(csv.reader(f))
  
    # Return key and data, so it can build a dictionary
    return key, data


#load_data('dgica.csv')

pool = concurrent.futures.ProcessPoolExecutor(max_workers=5)
data = pool.map(read_file, os.listdir('prices'))
data = list(data)

# Make it a hash table 
data = dict(data) 


print('done')
# Out:
# done

# %% [markdown]
# <b> 2 - Computing aggregations <b>

# %%
from dateutil.parser import parse

# Transform data into
# Hash table, hash table, list
stocks_data = {}
for stock,v in data.items():
   
    headers = v[0] # ['date', 'close', 'open', 'high', 'low', 'volume']
    stock_data = v[1:]
    
    # Loop through each header to build a list with its values
    header_data = {}
    for i, header in enumerate(headers):
        
        # Use header index to pick right item from the list
        #['2007-01-03', '55.380001', '54.880001', '55.75', '54.880001', '66000']
        # Parse data in the process as well
        if i > 0:
            values = [float(p[i]) for p in stock_data]
        else:
            # Parse date using dateutil.parser
            values = [parse(p[i]) for p in stock_data]
        header_data[header] = values
        
    # Build final hash table
    stocks_data[stock] = header_data
    
    #{'stock': 'date': [1,2,3,4],
    #           'volume': [1,2,3,4]}
#print(stocks_data['bokf'])

print('done')
# Out:
# done

# %%
from statistics import mean


# ['date', 'close', 'open', 'high', 'low', 'volume']

# Average closing price Apple (aapl)
print('Apple average closing price =', mean(stocks_data['aapl']['close']))
print()

# Average volume Apple (aapl)
print('Apple average volume =', mean(stocks_data['aapl']['volume']))
print()

# Highest price variation for apple
max_var = 0
max_var_index = -1
for i,h in enumerate(stocks_data['aapl']['high']):
    low = stocks_data['aapl']['low'][i]
    
    if (h - low) > max_var:
        max_var = h - low
        max_var_index = i
print('Highest price variation for apple =', max_var) 
print('date:', stocks_data['aapl']['date'][max_var_index])
print('high =', stocks_data['aapl']['high'][max_var_index])
print('low =', stocks_data['aapl']['low'][max_var_index])
print('volume =', stocks_data['aapl']['volume'][max_var_index])

print()
# Out:
# Apple average closing price = 257.17654040231656
#
# Apple average volume = 130112422.35521236
#
# Highest price variation for apple = 59.00000200000002
# date: 2010-05-06 00:00:00
# high = 258.249996
# low = 199.249994
# volume = 321465200.0

# %%
# Average closing for all stocks

print('Average closing for all stocks:')
mean_prices = [(stock,mean(stocks_data[stock]['close'])) for stock in stocks_data]
print(sorted(mean_prices, key=lambda x:x[1]))
# Out:
# Average closing for all stocks:
# [('blfs', 0.8122763011583011), ('apdn', 0.8241009938223938), ('bmra', 0.901011583011583), ('bcli', 0.9969415324324323), ('cyrx', 1.1615408884169884), ('clrb', 1.2045711436293436), ('cpst', 1.206953667953668), ('csbr', 1.2282443845854418), ('egt', 1.3293513513513513), ('aemd', 1.398042471042471), ('dfbg', 1.4005010393822395), ('alqa', 1.405298283011583), ('cpah', 1.4116189448441248), ('astc', 1.4152123552123552), ('chci', 1.4581224154440156), ('ctic', 1.494366311969112), ('eltk', 1.5323436293436294), ('dzsi', 1.5382316602316601), ('cool', 1.5475988922779924), ('cgnt', 1.5946138996138997), ('creg', 1.6028996138996139), ('casi', 1.617906349034749), ('admp', 1.7122164397683397), ('bnso', 1.7172548262548262), ('aezs', 1.7391445949806952), ('dynt', 1.822119691119691), ('apps', 1.8256061776061776), ('dysl', 1.8631660231660232), ('apri', 1.8681738996138995), ('crds', 1.8903166015444017), ('dlhc', 1.8903745173745172), ('cur', 1.907691699604743), ('ardm', 1.928069498069498), ('cpsh', 1.9615839865149602), ('cprx', 1.9762007722007722), ('cidm', 1.9935057915057917), ('cytr', 1.9986748837837838), ('atrs', 2.035023166023166), ('dram', 2.0592628378378377), ('artx', 2.0992316602316605), ('aris', 2.1661389961389963), ('cfbk', 2.174841698841699), ('crtn', 2.1850579150579152), ('bosc', 2.188019305019305), ('ffhl', 2.192687258687259), ('emms', 2.2464208494208493), ('abio', 2.2518008), ('clbs', 2.2820694980694984), ('bldp', 2.3273861003861005), ('drrx', 2.3527799227799227), ('camt', 2.402606177606178), ('basi', 2.4194633204633202), ('cbak', 2.4378957528957526), ('cthr', 2.4644787644787645), ('cris', 2.4645714285714284), ('fll', 2.4715752895752896), ('capr', 2.473247462919594), ('cemi', 2.4821776061776064), ('casm', 2.4918), ('abeo', 2.593220077220077), ('cdor', 2.6057721938223937), ('aehr', 2.6085559845559847), ('clwt', 2.6171322247104247), ('biol', 2.6383436347490345), ('cntf', 2.659563711969112), ('cycc', 2.667563561003861), ('aey', 2.6871505791505794), ('atec', 2.702578042857143), ('cyrn', 2.7131410714285717), ('dxtr', 2.7493397683397682), ('aame', 2.7796795366795366), ('asrv', 2.801169884169884), ('axas', 2.8366293436293435), ('dcth', 2.891166023166023), ('agen', 2.999889955984556), ('clsn', 3.00828185019305), ('drad', 3.053988416988417), ('casc', 3.062540716602317), ('arci', 3.1327799227799225), ('adxs', 3.166938612355212), ('apwc', 3.2336409266409265), ('edap', 3.2358030888030886), ('cui', 3.2413753598455597), ('cort', 3.2995482625482624), ('cytx', 3.3293219922779924), ('acls', 3.343806946718147), ('avir', 3.4036661768339767), ('ahpi', 3.4043899613899615), ('byfc', 3.4977644787644784), ('dswl', 3.529177606177606), ('extr', 3.5375019305019304), ('egan', 3.5465791505791504), ('cnit', 3.604745173745174), ('falc', 3.6092123552123554), ('cbli', 3.61026641042471), ('eng', 3.644196910810811), ('daio', 3.651555984555985), ('cmls', 3.678938223938224), ('dtrm', 3.7235559845559845), ('cbmx', 3.7302140003861), ('axgn', 3.82023166023166), ('axti', 3.8255212355212356), ('asur', 3.873123663706564), ('arql', 3.8744247104247105), ('cpss', 3.9003629343629345), ('evlv', 3.972590733590734), ('amrn', 3.992459461003861), ('cdti', 4.001780249420849), ('esxb', 4.032393822393822), ('else', 4.060752895752896), ('awre', 4.083567567567568), ('arwr', 4.130016216216216), ('cyan', 4.164428571428572), ('cers', 4.2464787644787645), ('fhco', 4.288459459459459), ('bsqr', 4.305370656370656), ('attu', 4.317359073359073), ('audc', 4.375227799227799), ('cnty', 4.444320463320464), ('emkr', 4.458320463320463), ('ctib', 4.690494208494208), ('cytk', 4.7425641938223935), ('bdsi', 4.8207065644787646), ('cgen', 4.882621621621621), ('arna', 4.915745173745174), ('cyccp', 4.965254826254826), ('ccur', 4.987629343629343), ('exfo', 4.995563706563707), ('arry', 5.182899613899614), ('edgw', 5.274084942084942), ('bwen', 5.326498072200772), ('bbgi', 5.338297297297298), ('eght', 5.531308880694981), ('eqfn', 5.558436266023166), ('acfc', 5.596733538610039), ('crme', 5.622293436293436), ('crws', 5.629 ...

# %% [markdown]
# <b> 3. Finding The Most Traded Stock Each Day <b>

# %%
import datetime

#{'stock': 'date': [1,2,3,4],
#          'volume': [1,2,3,4]}
stocks_date = {}
stocks_volume = {}
for stock in stocks_data.keys():
    for i,d in enumerate(stocks_data[stock]['date']):
        date = d.strftime('%Y-%m-%d')
        if  date not in stocks_date.keys():
            stocks_date[date] = (stocks_data[stock]['volume'][i], stock)
            stocks_volume[date] = stock
        else:
            if stocks_data[stock]['volume'][i] > stocks_date[date][0]:
                stocks_date[date] = (stocks_data[stock]['volume'][i], stock)
                stocks_volume[date] = stock
   
      
most_traded = []
for d in sorted(stocks_volume.keys()):
    most_traded.append([d,stocks_volume[d]])
    
print(most_traded)
# Out:
# [['2007-01-03', 'aapl'], ['2007-01-04', 'aapl'], ['2007-01-05', 'aapl'], ['2007-01-08', 'aapl'], ['2007-01-09', 'aapl'], ['2007-01-10', 'aapl'], ['2007-01-11', 'aapl'], ['2007-01-12', 'aapl'], ['2007-01-16', 'aapl'], ['2007-01-17', 'aapl'], ['2007-01-18', 'aapl'], ['2007-01-19', 'aapl'], ['2007-01-22', 'aapl'], ['2007-01-23', 'aapl'], ['2007-01-24', 'aapl'], ['2007-01-25', 'aapl'], ['2007-01-26', 'aapl'], ['2007-01-29', 'aapl'], ['2007-01-30', 'aapl'], ['2007-01-31', 'aapl'], ['2007-02-01', 'aapl'], ['2007-02-02', 'aapl'], ['2007-02-05', 'aapl'], ['2007-02-06', 'aapl'], ['2007-02-07', 'aapl'], ['2007-02-08', 'aapl'], ['2007-02-09', 'aapl'], ['2007-02-12', 'aapl'], ['2007-02-13', 'aapl'], ['2007-02-14', 'aapl'], ['2007-02-15', 'bidu'], ['2007-02-16', 'aapl'], ['2007-02-20', 'aapl'], ['2007-02-21', 'aapl'], ['2007-02-22', 'aapl'], ['2007-02-23', 'aapl'], ['2007-02-26', 'aapl'], ['2007-02-27', 'aapl'], ['2007-02-28', 'aapl'], ['2007-03-01', 'aapl'], ['2007-03-02', 'aapl'], ['2007-03-05', 'aapl'], ['2007-03-06', 'aapl'], ['2007-03-07', 'aapl'], ['2007-03-08', 'cy'], ['2007-03-09', 'aapl'], ['2007-03-12', 'aapl'], ['2007-03-13', 'aapl'], ['2007-03-14', 'aapl'], ['2007-03-15', 'aapl'], ['2007-03-16', 'aapl'], ['2007-03-19', 'aapl'], ['2007-03-20', 'aapl'], ['2007-03-21', 'aapl'], ['2007-03-22', 'aapl'], ['2007-03-23', 'aapl'], ['2007-03-26', 'aapl'], ['2007-03-27', 'aapl'], ['2007-03-28', 'aapl'], ['2007-03-29', 'aapl'], ['2007-03-30', 'aapl'], ['2007-04-02', 'aapl'], ['2007-04-03', 'aapl'], ['2007-04-04', 'aapl'], ['2007-04-05', 'aapl'], ['2007-04-09', 'aapl'], ['2007-04-10', 'aapl'], ['2007-04-11', 'aapl'], ['2007-04-12', 'aapl'], ['2007-04-13', 'aapl'], ['2007-04-16', 'aapl'], ['2007-04-17', 'aapl'], ['2007-04-18', 'aapl'], ['2007-04-19', 'ebay'], ['2007-04-20', 'aapl'], ['2007-04-23', 'aapl'], ['2007-04-24', 'aapl'], ['2007-04-25', 'aapl'], ['2007-04-26', 'aapl'], ['2007-04-27', 'aapl'], ['2007-04-30', 'aapl'], ['2007-05-01', 'aapl'], ['2007-05-02', 'aapl'], ['2007-05-03', 'aapl'], ['2007-05-04', 'aapl'], ['2007-05-07', 'aapl'], ['2007-05-08', 'aapl'], ['2007-05-09', 'aapl'], ['2007-05-10', 'aapl'], ['2007-05-11', 'aapl'], ['2007-05-14', 'aapl'], ['2007-05-15', 'aapl'], ['2007-05-16', 'aapl'], ['2007-05-17', 'aapl'], ['2007-05-18', 'aapl'], ['2007-05-21', 'aapl'], ['2007-05-22', 'aapl'], ['2007-05-23', 'aapl'], ['2007-05-24', 'aapl'], ['2007-05-25', 'aapl'], ['2007-05-29', 'aapl'], ['2007-05-30', 'aapl'], ['2007-05-31', 'aapl'], ['2007-06-01', 'aapl'], ['2007-06-04', 'aapl'], ['2007-06-05', 'aapl'], ['2007-06-06', 'aapl'], ['2007-06-07', 'aapl'], ['2007-06-08', 'aapl'], ['2007-06-11', 'aapl'], ['2007-06-12', 'aapl'], ['2007-06-13', 'aapl'], ['2007-06-14', 'aapl'], ['2007-06-15', 'aapl'], ['2007-06-18', 'aapl'], ['2007-06-19', 'aapl'], ['2007-06-20', 'aapl'], ['2007-06-21', 'aapl'], ['2007-06-22', 'aapl'], ['2007-06-25', 'aapl'], ['2007-06-26', 'aapl'], ['2007-06-27', 'aapl'], ['2007-06-28', 'aapl'], ['2007-06-29', 'aapl'], ['2007-07-02', 'aapl'], ['2007-07-03', 'aapl'], ['2007-07-05', 'aapl'], ['2007-07-06', 'aapl'], ['2007-07-09', 'aapl'], ['2007-07-10', 'aapl'], ['2007-07-11', 'aapl'], ['2007-07-12', 'aapl'], ['2007-07-13', 'aapl'], ['2007-07-16', 'aapl'], ['2007-07-17', 'aapl'], ['2007-07-18', 'aapl'], ['2007-07-19', 'aapl'], ['2007-07-20', 'aapl'], ['2007-07-23', 'aapl'], ['2007-07-24', 'aapl'], ['2007-07-25', 'aapl'], ['2007-07-26', 'aapl'], ['2007-07-27', 'aapl'], ['2007-07-30', 'aapl'], ['2007-07-31', 'aapl'], ['2007-08-01', 'aapl'], ['2007-08-02', 'aapl'], ['2007-08-03', 'aapl'], ['2007-08-06', 'aapl'], ['2007-08-07', 'aapl'], ['2007-08-08', 'aapl'], ['2007-08-09', 'aapl'], ['2007-08-10', 'aapl'], ['2007-08-13', 'aapl'], ['2007-08-14', 'aapl'], ['2007-08-15', 'aapl'], ['2007-08-16', 'aapl'], ['2007-08-17', 'aapl'], ['2007-08-20', 'aapl'], ['2007-08-21', 'aapl'], ['2007-08-22', 'aapl'], ['2007-08-23', 'aapl'], ['2007-08-24', 'aapl'], ['2007-08-27', 'aapl'], ['2007-08-28', 'aapl'], ['2007-08-29', 'aapl'], ['2007-08-30', 'a ...

# %%
high_volume = {}

for stock, prices in stocks_data.items():    
    for i, d in enumerate(prices['date']):        
        if d not in high_volume.keys():
            high_volume[d] = 0
        high_volume[d] += prices['volume'][i]
               
# Sorte by value and keep top 10 only
top_10 = sorted(high_volume.items(), key=lambda x: x[1], reverse=True)[:10]
print("TOP 10 day trades by volume:")
print(top_10)
# Out:
# TOP 10 day trades by volume:
# [(datetime.datetime(2008, 1, 23, 0, 0), 1964583900.0), (datetime.datetime(2008, 10, 10, 0, 0), 1770266900.0), (datetime.datetime(2007, 7, 26, 0, 0), 1611272800.0), (datetime.datetime(2008, 10, 8, 0, 0), 1599183500.0), (datetime.datetime(2008, 1, 22, 0, 0), 1578877700.0), (datetime.datetime(2008, 2, 7, 0, 0), 1559032100.0), (datetime.datetime(2008, 9, 29, 0, 0), 1555072400.0), (datetime.datetime(2007, 11, 8, 0, 0), 1553880500.0), (datetime.datetime(2008, 1, 16, 0, 0), 1536176400.0), (datetime.datetime(2008, 1, 24, 0, 0), 1533363200.0)]

# %%
for d,v in top_10:
    print('Date:',d)
    print('Total Volume:',v)
    
    
    for stock, price in stocks_data.items():
        i = price['date'].index(d)
        print('Stock =',stock,' Close Price =',price['close'][i] )
        #print(i)
        #print(price['close'][i])
        
    print('------------------------------------')
# Out:
# Date: 2008-01-23 00:00:00
# Total Volume: 1964583900.0
# Stock = abcb  Close Price = 15.320042
# Stock = evlv  Close Price = 5.78
# Stock = bybk  Close Price = 12.5
# Stock = cy  Close Price = 22.200013
# Stock = arlp  Close Price = 34.450001
# Stock = fhco  Close Price = 2.5
# Stock = cffi  Close Price = 30.799999
# Stock = cme  Close Price = 609.990005
# Stock = cnbka  Close Price = 20.200001
# Stock = apwc  Close Price = 4.6
# Stock = bvsn  Close Price = 1.55
# Stock = cent  Close Price = 4.41
# Stock = bwinb  Close Price = 27.15
# Stock = buse  Close Price = 20.979978
# Stock = colm  Close Price = 41.990002
# Stock = amd  Close Price = 7.56
# Stock = cenx  Close Price = 42.490002
# Stock = cbsh  Close Price = 43.240306
# Stock = clsn  Close Price = 4.710001
# Stock = becn  Close Price = 8.63
# Stock = cfnb  Close Price = 10.12
# Stock = acls  Close Price = 4.0
# Stock = amed  Close Price = 45.830002
# Stock = ardm  Close Price = 1.29
# Stock = asrvp  Close Price = 24.559999
# Stock = abax  Close Price = 35.279999
# Stock = csbk  Close Price = 10.079999
# Stock = csbr  Close Price = 1.139999
# Stock = endp  Close Price = 23.92
# Stock = chscp  Close Price = 25.09
# Stock = arcw  Close Price = 4.899995
# Stock = ezpw  Close Price = 11.42
# Stock = abtl  Close Price = 2.32
# Stock = clct  Close Price = 9.980003
# Stock = emitf  Close Price = 43.000084
# Stock = alsk  Close Price = 13.13
# Stock = dsgx  Close Price = 3.66
# Stock = fmbi  Close Price = 28.01
# Stock = dcth  Close Price = 1.28
# Stock = discb  Close Price = 23.879993
# Stock = dcom  Close Price = 13.74
# Stock = dgica  Close Price = 17.690001
# Stock = ctib  Close Price = 3.62
# Stock = emkr  Close Price = 10.75
# Stock = arcb  Close Price = 24.26
# Stock = dest  Close Price = 15.11
# Stock = eqix  Close Price = 71.279999
# Stock = fcnca  Close Price = 127.080002
# Stock = ctic  Close Price = 1.429999
# Stock = bcrx  Close Price = 5.29
# Stock = fdef  Close Price = 19.65
# Stock = alxn  Close Price = 66.190002
# Stock = dtrm  Close Price = 1.67
# Stock = cdor  Close Price = 5.929999
# Stock = avir  Close Price = 3.730074
# Stock = educ  Close Price = 5.89
# Stock = dave  Close Price = 10.2
# Stock = cplp  Close Price = 19.040001
# Stock = chrw  Close Price = 51.009998
# Stock = cvco  Close Price = 37.619999
# Stock = exas  Close Price = 2.9
# Stock = cinf  Close Price = 37.130001
# Stock = djco  Close Price = 40.310001
# Stock = arry  Close Price = 6.6
# Stock = flex  Close Price = 9.66
# Stock = elgx  Close Price = 2.67
# Stock = dfbg  Close Price = 0.889999
# Stock = ango  Close Price = 19.790001
# Stock = bsf  Close Price = 13.850001
# Stock = emcf  Close Price = 25.799999
# Stock = ccmp  Close Price = 33.82
# Stock = disca  Close Price = 23.29
# Stock = dakt  Close Price = 19.219999
# Stock = atri  Close Price = 120.0
# Stock = cgen  Close Price = 2.52
# Stock = essa  Close Price = 11.75
# Stock = cnob  Close Price = 10.26
# Stock = csco  Close Price = 24.030001
# Stock = dxyn  Close Price = 7.96
# Stock = bgfv  Close Price = 11.75
# Stock = ccbg  Close Price = 29.91
# Stock = clwt  Close Price = 2.410024
# Stock = cldx  Close Price = 0.629975
# Stock = dram  Close Price = 3.200003
# Stock = emci  Close Price = 23.62
# Stock = bnso  Close Price = 2.48
# Stock = fcap  Close Price = 16.25
# Stock = bjri  Close Price = 15.92
# Stock = else  Close Price = 4.65
# Stock = actg  Close Price = 8.29
# Stock = fbms  Close Price = 22.5
# Stock = crtn  Close Price = 2.35
# Stock = cbak  Close Price = 4.4
# Stock = adrd  Close Price = 27.59
# Stock = cers  Close Price = 6.15
# Stock = aaww  Close Price = 49.990002
# Stock = dynt  Close Price = 0.99
# Stock = ebay  Close Price = 28.939999
# Stock = ehth  Close Price = 31.02
# Stock = cern  Close Price = 53.950001
# Stock = dspg  Close Price = 10.29
# Stock = ebtc  Close Price = 12.85
# Stock = flxs  Close Price = 11.38
# Stock = chnr  Close Price = 16.74
# Stock = belfb  Close Price = 27.969999
# Stock = atro  Close Price = 34.190051
# Stock = clbs  Close Price = 1.6
# Stock = dswl  Close Price = 5.96
# Stock = crnt  Close Price = 8.69
# Stock = clrb  Close Price = 0.749999
# Stock = ctsh  Close Price = 27.0
# Stock = bldr  Close Price = 6.35
# Stock = cmct  Close Price = 9.55
# Stock = ancx  Close Price = 6.07
# Stock = chdn  Close Price = 50.119999
# Stock = cac  Close Price = 32.000001
# Stock = cutr  Close Price = 14.34
# Stock = bdge  Close Price = 22.0
# Stock = cznc  Close Price = 17.73
# Stock = bdsi  Close Price = 2.35
# Stock = brkr  Close Price = 11.67
# Stock = carv  Close Price = 13.700685
# Stock = epay  Close Price = 12.27
# Stock = arii  Close Price = 17.0
# Stock = cnxn  Close Price = 10.58
# Stock = csgs  Close Price = 13.35
# Stock = arci  Close Price = 6.19
# Stock = ea  Close Price = 48.07
# Stock = cacc  Close Price = 14.55
# Stock = algn  Close Price = 13.48
# Stock = crvl  Close Price = 24.82
# Stock = aplp  Close Price = 31.709999
# Stock = ffiv  Close Price = 20.18
# Stock = etfc  Close Price = 3.46
# Stock = cspi  Close Price = 7.11
# Stock = cald  Close Price = 3.75
# Stock = aaon  Close Price = 17.850003
# Stock = diod  Close Price = 22.969999
# Stock = abco  Close Price = 62.599998
# Stock = cthr  Close Price = 1.85
# Stock = atvi  Close Price = 26.66
# Stock = bcpc  Close Price = 20.890005
# Stock = bwld  Close Price = 22.950001
# Stock = chy  Close Price = 13.54
# Stock = cown  Close Price = 10.81
# Stock = akrx  Close Price = 7.5
# Stock = amag  Close Price = 59.93
# Stock = cwst  Close Price = 11.71
# Stock = cbfv  Close Price = 17.450001
# Stock = bebe  Close Price = 10.9
# Stock = artx  Close Price = 1.75
# Stock = alco  Close Price = 43.889999
# Stock = amat  Close Price = 18.1
# Stock = avhi  Close Price = 46.669998
# Stock = clro  Close Price = 4.8
# Stock = bwina  Close Price = 24.549999
# Stock = eei  Close Price = 11.15
# Stock = flir  Close Price = 29.709999
# Stock = cmtl  Close Price = 46.380001
# Stock = csiq  Close Price = 17.530001
# Stock = acta  Close Price = 9.71
# Stock = blfs  Close Price = 0.070001
# Stock = brcd  Close Price = 6.26
# Stock = cfbk  Close Price = 4.41
# Stock = cui  Close Price = 0.274973
# Stock = ctrn  Close Price = 12.36
# Stock = amtd  Close Price = 16.75
# Stock = asml  Close Price = 26.42
# Stock = apog  Close Price = 16.6
# Stock = eric  Close Price = 22.059999
# Stock = efsc  Close Price = 22.940001
# Stock = caty  Close Price = 25.709999
# Stock = acor  Close Price = 23.049999
# Stock = chmg  Close Price = 26.5
# Stock = biib  Close Price = 59.23
# Stock = amwd  Close Price = 19.16
# Stock = asna  Close Price = 11.96
# Stock = cvly  Close Price = 15.79992
# Stock = cvbf  Close Price = 10.7
# Stock = eltk  Close Price = 2.49
# Stock = astc  Close Price = 1.24
# Stock = cpst  Close Price = 1.33
# Stock = fisv  Close Price = 48.700001
# Stock = amrn  Close Price = 1.81
# Stock = club  Close Price = 8.93
# Stock = chi  Close Price = 15.06
# Stock = capr  Close Price = 4.5
# Stock = drys  Close Price = 55.23998
# Stock = finl  Close Price = 1.91
# Stock = ffin  Close Price = 37.52001
# Stock = exls  Close Price = 19.059999
# Stock = cvcy  Close Price = 10.76
# Stock = celg  Close Price = 53.599998
# Stock = ccoi  Close Price = 17.84
# Stock = cigi  Close Price = 21.769993
# Stock = biol  Close Price = 2.85999
# Stock = achc  Close Price = 2.57
# Stock = fbss  Close Price = 15.8
# Stock = achn  Close Price = 4.65
# Stock = amot  Close Price = 4.7
# Stock = cbio  Close Price = 7.05
# Stock = evol  Close Price = 2.02
# Stock = ffkt  Close Price = 26.940001
# Stock = fbnc  Close Price = 20.35
# Stock = fll  Close Price = 2.04
# Stock = cyrn  Close Price = 4.11
# Stock = crws  Close Price = 3.2
# Stock = falc  Close Price = 8.6
# Stock = dnbf  Close Price = 16.24
# Stock = cbli  Close Price = 2.53
# Stock = fast  Close Price = 39.970001
# Stock = egan  Close Price = 0.9
# Stock = dysl  Close Price = 1.6
# Stock = fcco  Close Price = 13.5
# Stock = avnw  Close Price = 14.499994
# Stock = airt  Close Price = 8.88
# Stock = expo  Close Price = 29.030001
# Stock = ctas  Close Price = 32.490002
# Stock = cuba  Close Price = 7.01
# Stock = fisi  Close Price = 17.469999
# Stock = cvgw  Close Price = 19.42
# Stock = cprx  Close Price = 3.05
# Stock = alot  Close Price = 9.86
# Stock = czfc  Close Price = 9.01
# Stock = aemd  Close Price = 0.65
# Stock = dzsi  Close Price = 0.98
# Stock = bont  Close Price = 6.97
# Stock = bosc  Close Price = 1.96
# Stock = ceco  Close Price = 17.43
# Stock = apri  Close Price = 1.320001
# Stock = cizn  Close Price = 18.25
# Stock = acfc  Close Price = 8.700001
# Stock = chco  Close Price = 36.41
# Stock = crzo  Close Price = 45.470001
# Stock = ecol  Close Price = 21.9
# Stock = chfc  Close Price = 24.780001
# Stock = ffbc  Close Price = 11.02
# Stock = asur  Close Price = 0.700001
# Stock = bksc  Close Price = 13.940004
# Stock = arlz  Close Price = 12.7
# Stock = faro  Close Price = 21.27
# Stock = acgl  Close Price = 69.600002
# Stock = aey  Close Price = 4.8
# Stock = adre  Close Price = 48.299999
# Stock = ccrn  Close Price = 12.26
# Stock = aray  Close Price = 15.8
# Stock = aimc  Close Price = 11.94
# Stock = ewbc  Close Price = 24.719999
# Stock = bbox  Close Price = 28.889999
# Stock = dgii  Close Price = 13.51
# Stock = cytk  Close Price = 3.570071
# Stock = boom  Close Price = 50.439999
# Stock = casi  Close Price = 1.150011
# Stock = camp  Close Price = 2.65
# Stock = eght  Close Price = 1.07
# Stock = farm  Close Price = 23.629999
# Stock = adru  Close Price = 27.85
# Stock = dorm  Close Price = 11.01
# Stock = dgas  Close Price = 25.59
# Stock = czwi  Close Price = 8.25
# Stock = esxb  Close Price = 7.46
# Stock = cart  Close Price = 13.05
# Stock = core  Close Price = 24.709999
# Stock = csq  Close Price = 13.18
# Stock = bcbp  Close Price = 14.2
# Stock = asfi  Close Price = 19.940001
# Stock = basi  Close Price = 7.6
# Stock = bset  Close Price = 11.53
# Stock = dwaq  Close Price = 46.040001
# Stock = agys  Close Price = 14.79
# Stock = cvv  Close Price = 3.19
# Stock = bokf  Close Price = 51.669998
# Stock = cool  Close Price = 0.890018
# Stock = cfcb  Close Price = 17.958204
# Stock = ctg  Close Price = 4.25
# Stock = cemi  Close Price = 0.22
# Stock = ainv  Close Price = 15.21
# Stock = brid  Close Price = 6.62
# Stock = fele  Close Price = 37.380001
# Stock = amkr  Close Price = 6.69
# Stock = cidm  Close Price = 2.43
# Stock = clfd  Close Price = 1.05
# Stock = crus  Close Price = 4.51
# Stock = dxpe  Close Price = 34.59
# Stock = bmrc  Close Price = 27.66
# Stock = cgo  Close Price = 17.18
# Stock = ctbi  Close Price = 28.720001
# Stock = bios  Close Price = 7.9
# Stock = cris  Close Price = 1.43
# Stock = cdti  Close Price = 15.970319
# Stock = dwsn  Close Price = 8.080052
# Stock = egbn  Close Price = 11.890005
# Stock = cass  Close Price = 27.920003
# Stock = emms  Close Price = 2.98
# Stock = calm  Close Price = 23.99
# Stock = ctxs  Close Price = 31.999999
# Stock = edgw  Close Price = 6.93
# Stock = anss  Close Price = 33.860001
# Stock = esnd  Close Price = 46.970001
# Stock = afsi  Close Price = 13.79
# Stock = casy  Close Price = 27.219999
# Stock = esio  Close Price = 17.389999
# Stock = aezs  Close Price = 1.630003
# Stock = banr  Close Price = 22.050441
# Stock = bsrr  Close Price = 23.450001
# Stock = eqfn  Close Price = 7.2
# Stock = amzn  Close Price = 73.970001
# Stock = camt  Close Price = 1.48
# Stock = cpss  Close Price = 2.64
# Stock = chkp  Close Price = 21.200001
# Stock = dish  Close Price = 28.610001
# Stock = cvti  Close Price = 7.1
# Stock = arql  Close Price = 4.73
# Stock = ahpi  Close Price = 7.24
# Stock = csx  Close Price = 45.51
# Stock = amsf  Close Price = 14.25
# Stock = cpsh  Close Price = 2.25
# Stock = bmra  Close Price = 1.2
# Stock = aeis  Close Price = 9.98
# Stock = cmcsa  Close Price = 17.26
# Stock = afam  Close Price = 18.9
# Stock = aobc  Close Price = 4.16
# Stock = coke  Close Price = 60.919998
# Stock = exel  Close Price = 7.46
# Stock = alqa  Close Price = 0.330041
# Stock = agen  Close Price = 2.52005
# Stock = ceva  Close Price = 9.78
# Stock = bncn  Close Price = 15.22
# Stock = cwco  Close Price = 26.59
# Stock = asrv  Close Price = 2.53
# Stock = akam  Close Price = 27.790001
# Stock = airm  Close Price = 42.87
# Stock = chci  Close Price = 0.709999
# Stock = bpopn  Close Price = 25.09
# Stock = dmrc  Close Price = 7.38
# Stock = elon  Close Price = 12.98
# Stock = ahgp  Close Price = 23.459999
# Stock = cffn  Close Price = 31.22
# Stock = bobe  Close Price = 28.120001
# Stock = alks  Close Price = 14.05
# Stock = brew  Close Price = 5.89
# Stock = apdn  Close Price = 0.130026
# Stock = bbby  Close Price = 31.379999
# Stock = flws  Close Price = 7.04
# Stock = exfo  Close Price = 4.11
# Stock = azpn  Close Price = 12.73
# Stock = bde  Close Price = 5.71
# Stock = ctrp  Close Price = 45.93
# Stock = cwbc  Close Price = 9.0
# Stock = cmls  Close Price = 5.85
# Stock = eeft  Close Price = 26.1
# Stock = baby  Close Price = 18.01
# Stock = cfnl  Close Price = 7.75
# Stock = alny  Close Price = 31.940001
# Stock = bmtc  Close Price = 21.15
# Stock = cdzi  Close Price = 17.190001
# Stock = adp  Close Price = 39.480001
# Stock = ande  Close Price = 43.069994
# Stock = fccy  Close Price = 14.950091
# Stock = atec  Close Price = 4.959998
# Stock = dox  Close Price = 32.889999
# Stock = bmrn  Close Price = 36.990002
# Stock = aubn  Close Price = 22.299999
# Stock = ebix  Close Price = 64.999979
# Stock = cake  Close Price = 20.07
# Stock = cgnt  Close Price = 2.77
# Stock = arow  Close Price = 22.029953
# Stock = cpsi  Close Price = 21.25
# Stock = atlo  Close Price = 18.75
# Stock = apps  Close Price = 4.25
# Stock = banf  Close Price = 44.779999
# Stock = cycc  Close Price = 5.150017
# Stock = abio  Close Price = 1.489404
# Stock = adra  Close Price = 30.51
# Stock = aehr  Close Price = 6.6
# Stock = crmt  Close Price = 10.7
# Stock = aciw  Close Price = 13.570001
# Stock = dmlp  Close Price = 19.110001
# Stock = acnb  Close Price = 14.3
# Stock = egt  Close Price = 3.92
# Stock = cnmd  Close Price = 23.059999
# Stock = cort  Close Price = 2.54
# Stock = eng  Close Price = 9.64
# Stock = cnty  Close Price = 4.2
# Stock = cban  Close Price = 13.8
# Stock = dxcm  Close Price = 9.02
# Stock = cytx  Close Price = 5.090002
# Stock = eml  Close Price = 17.799999
# Stock = anik  Close Price = 11.32
# Stock = dlhc  Close Price = 0.75
# Stock = cresy  Close Price = 17.239956
# Stock = bbh  Close Price = 159.540001
# Stock = conn  Close Price = 18.629999
# Stock = cvlt  Close Price = 17.24
# Stock = ccne  Close Price = 13.38
# Stock = caas  Close Price = 6.09
# Stock = atrc  Close Price = 13.01
# Stock = entg  Close Price = 7.3
# Stock = adi  Close Price = 27.99
# Stock = feim  Close Price = 8.94
# Stock = ccur  Close Price = 0.69
# Stock = cyccp  Close Price = 4.25
# Stock = dxtr  Close Price = 9.41
# Stock = cohu  Close Price = 14.66
# Stock = attu  Close Price = 0.47
# Stock = eslt  Close Price = 58.709999
# Stock = bcor  Close Price = 9.15
# Stock = atsg  Close Price = 2.9
# Stock = cmpr  Close Price = 30.73
# Stock = csfl  Close Price = 14.06
# Stock = bsqr  Close Price = 6.12
# Stock = cprt  Close Price = 38.970001
# Stock = abeo  Close Price = 2.9
# Stock = evbs  Close Price = 17.08
# Stock = cohr  Close Price = 23.67
# Stock = aste  Close Price = 29.49
# Stock = cnit  Close Price = 7.17
# Stock = exac  Close Price = 22.379999
# Stock = brks  Close Price = 11.63
# Stock = csii  Close Price = 1.97
# Stock = clmt  Close Price = 32.200001
# Stock = bbsi  Close Price = 18.25
# Stock = arcc  Close Price = 14.23
# Stock = admp  Close Price = 0.049997
# Stock = cntf  Close Price = 3.9
# Stock = cobz  Close Price = 15.66
# Stock = atrs  Close Price = 0.88
# Stock = bbgi  Close Price = 4.52
# Stock = expd  Close Price = 47.23
# Stock = esca  Close Price = 8.4
# Stock = egle  Close Price = 20.300007
# Stock = arrs  Close Price = 7.49
# Stock = audc  Close Price = 3.9
# Stock = cbmx  Close Price = 8.300004
# Stock = call  Close Price = 0.38
# Stock = cswc  Close Price = 125.699997
# Stock = brkl  Close Price = 10.07
# Stock = depo  Close Price = 3.58
# Stock = aapl  Close Price = 139.070005
# Stock = cray  Close Price = 5.65
# Stock = amrb  Close Price = 17.580003
# Stock = ctws  Close Price = 23.42
# Stock = acad  Close Price = 11.52
# Stock = chke  Close Price = 32.439999
# Stock = acxm  Close Price = 9.0
# Stock = anip  Close Price = 3.560285
# Stock = drad  Close Price = 2.64
# Stock = cmco  Close Price = 24.99
# Stock = asys  Close Price = 10.02
# Stock = cnsl  Close Price = 16.01
# Stock = aegn  Close Price = 12.31
# Stock = bbry  Close Price = 88.0
# Stock = bkmu  Close Price = 11.6
# Stock = chfn  Close Price = 34.999997
# Stock = cdns  Close Price = 14.46
# Stock = fbiz  Close Price = 16.0
# Stock = algt  Close Price = 26.76
# Stock = casc  Close Price = 1.51
# Stock = extr  Close Price = 3.09
# Stock = arwr  Close Price = 2.54
# Stock = csgp  Close Price = 40.189999
# Stock = edap  Close Price = 3.96
# Stock = axdx  Close Price = 3.75
# Stock = dwch  Close Price = 6.45
# Stock = civb  Close Price = 13.46
# Stock = acet  Close Price = 7.22
# Stock = cvgi  Close Price = 10.29
# Stock = cetv  Close Price = 88.699997
# Stock = aame  Close Price = 1.48
# Stock = aaxn  Close Price = 9.14
# Stock = byfc  Close Price = 8.0
# Stock = adxs  Close Price = 0.14
# Stock = cunb  Close Price = 14.5
# Stock = atni  Close Price = 32.02
# Stock = cpah  Close Price = 0.4
# Stock = amgn  Close Price = 44.75
# Stock = bidu  Close Price = 270.200005
# Stock = axgn  Close Price = 1.75
# Stock = cyan  Close Price = 1.28
# Stock = cytr  Close Price = 1.829951
# Stock = atax  Close Price = 6.32
# Stock = cbrl  Close Price = 29.719999
# Stock = efii  Close Price = 12.98
# Stock = evep  Close Price = 26.9
# Stock = bstc  Close Price = 11.5
# Stock = car  Close Price = 10.03
# Stock = cpla  Close Price = 56.970001
# Stock = amnb  Close Price = 19.0
# Stock = crox  Close Price = 29.35
# Stock = dhil  Close Price = 69.839996
# Stock = dvax  Close Price = 5.54
# Stock = daio  Close Price = 4.89
# Stock = cur  Close Price = 2.96
# Stock = ffhl  Close Price = 3.41
# Stock = adsk  Close Price = 40.75
# Stock = centa  Close Price = 3.96
# Stock = crds  Close Price = 0.6
# Stock = axas  Close Price = 3.27
# Stock = blkb  Close Price = 27.48
# Stock = awre  Close Price = 3.83
# Stock = adtn  Close Price = 19.9
# Stock = flic  Close Price = 18.25
# Stock = ecpg  Close Price = 7.4
# Stock = anat  Close Price = 127.919998
# Stock = aris  Close Price = 1.6
# Stock = esgr  Close Price = 107.220001
# Stock = bcli  Close Price = 0.60003
# Stock = belfa  Close Price = 31.83
# Stock = amri  Close Price = 14.4
# Stock = agii  Close Price = 40.770008
# Stock = dltr  Close Price = 25.370001
# Stock = expe  Close Price = 23.389999
# Stock = cash  Close Price = 32.18
# Stock = amsc  Close Price = 19.260001
# Stock = denn  Close Price = 3.2
# Stock = crai  Close Price = 44.5
# Stock = ca  Close Price = 21.43
# Stock = arna  Close Price = 8.34
# Stock = bwen  Close Price = 11.2
# Stock = cece  Close Price = 8.67
# Stock = bgcp  Close Price = 11.59
# Stock = cost  Close Price = 68.610001
# Stock = elos  Close Price = 14.7
# Stock = avdl  Close Price = 9.38
# Stock = dgicb  Close Price = 18.25
# Stock = bfin  Close Price = 15.92
# Stock = arkr  Close Price = 32.0
# Stock = fizz  Close Price = 7.36
# Stock = creg  Close Price = 2.24
# Stock = cgnx  Close Price = 16.35
# Stock = abmd  Close Price = 13.34
# Stock = esrx  Close Price = 64.309998
# Stock = bofi  Close Price = 7.0
# Stock = cybe  Close Price = 10.12
# Stock = boch  Close Price = 8.41
# Stock = bpop  Close Price = 10.71
# Stock = aal  Close Price = 13.14
# Stock = botj  Close Price = 12.999997
# Stock = cree  Close Price = 28.549999
# Stock = alog  Close Price = 63.639999
# Stock = banfp  Close Price = 25.0
# Stock = cacb  Close Price = 14.110001
# Stock = axti  Close Price = 4.45
# Stock = amswa  Close Price = 7.71
# Stock = crme  Close Price = 7.02
# Stock = bldp  Close Price = 4.27
# Stock = artw  Close Price = 22.85
# Stock = ffic  Close Price = 15.2
# Stock = dvcr  Close Price = 10.61
# Stock = artna  Close Price = 18.360001
# Stock = cyrx  Close Price = 0.9996
# Stock = allt  Close Price = 4.15
# Stock = drrx  Close Price = 6.43
# Stock = esbk  Close Price = 19.5
# Stock = aiq  Close Price = 9.98
# Stock = adbe  Close Price = 34.349998
# Stock = colb  Close Price = 25.440001
# Stock = casm  Close Price = 5.1
# Stock = avav  Close Price = 23.59
# Stock = atlc  Close Price = 10.86
# ------------------------------------
# Date: 2008-10-10 00:00:00
# Total Volume: 1770266900.0
# Stock = abcb  Close Price = 12.980029
# Stock = evlv  Close Price = 1.19
# Stock = bybk  Close Price = 8.5
# Stock = cy  Close Price = 3.59
# Stock = arlp  Close Price = 24.5
# Stock = fhco  Close Price = 2.79
# Stock = cffi  Close Price = 17.01
# Stock = cme  Close Price = 393.120003
# Stock = cnbka  Close Price = 15.02
# Stock = apwc  Close Price = 2.9
# Stock = bvsn  Close Price = 0.52
# Stock = cent  Close Price = 4.14
# Stock = bwinb  Close Price = 17.610001
# Stock = buse  Close Price = 17.889981
# Stock = colm  Close Price = 35.720001
# Stock = amd  Close Price = 3.81
# Stock = cenx  Close Price = 13.19
# Stock = cbsh  Close Price = 42.18028
# Stock = clsn  Close Price = 2.2
# Stock = becn  Close Price = 14.59
# Stock = cfnb  Close Price = 9.95
# Stock = acls  Close Price = 0.76
# Stock = amed  Close Price = 44.779999
# Stock = ardm  Close Price = 0.23
# Stock = asrvp  Close Price = 16.91
# Stock = abax  Close Price = 14.31
# Stock = csbk  Close Price = 10.99
# Stock = csbr  Close Price = 0.59
# Stock = endp  Close Price = 14.81
# Stock = chscp  Close Price = 24.65
# Stock = arcw  Close Price = 3.839996
# Stock = ezpw  Close Price = 12.57
# Stock = abtl  Close Price = 0.59
# Stock = clct  Close Price = 4.280001
# Stock = emitf  Close Price = 13.240026
# Stock = alsk  Close Price = 10.43
# Stock = dsgx  Close Price = 2.43
# Stock = fmbi  Close Price = 23.610001
# Stock = dcth  Close Price = 1.08
# Stock = discb  Close Price = 14.199998
# Stock = dcom  Close Price = 15.55
# Stock = dgica  Close Price = 13.18
# Stock = ctib  Close Price = 3.72
# Stock = emkr  Close Price = 3.61
# Stock = arcb  Close Price = 30.639999
# Stock = dest  Close Price = 11.37
# Stock = eqix  Close Price = 54.580002
# Stock = fcnca  Close Price = 152.199997
# Stock = ctic  Close Price = 0.48
# Stock = bcrx  Close Price = 1.79
# Stock = fdef  Close Price = 10.53
# Stock = alxn  Close Price = 34.209999
# Stock = dtrm  Close Price = 0.98
# Stock = cdor  Close Price = 2.16
# Stock = avir  Close Price = 3.340067
# Stock = educ  Close Price = 3.6
# Stock = dave  Close Price = 4.19
# Stock = cplp  Close Price = 7.15
# Stock = chrw  Close Price = 41.389999
# Stock = cvco  Close Price = 30.030001
# Stock = exas  Close Price = 0.75
# Stock = cinf  Close Price = 19.34
# Stock = djco  Close Price = 39.5
# Stock = arry  Close Price = 4.26
# Stock = flex  Close Price = 4.97
# Stock = elgx  Close Price = 1.33
# Stock = dfbg  Close Price = 0.699999
# Stock = ango  Close Price = 12.29
# Stock = bsf  Close Price = 7.419999
# Stock = emcf  Close Price = 21.75
# Stock = ccmp  Close Price = 26.719999
# Stock = disca  Close Price = 11.12
# Stock = dakt  Close Price = 12.9
# Stock = atri  Close Price = 93.110001
# Stock = cgen  Close Price = 1.55
# Stock = essa  Close Price = 12.95
# Stock = cnob  Close Price = 7.85
# Stock = csco  Close Price = 17.23
# Stock = dxyn  Close Price = 6.14
# Stock = bgfv  Close Price = 7.42
# Stock = ccbg  Close Price = 28.75
# Stock = clwt  Close Price = 0.99001
# Stock = cldx  Close Price = 7.81
# Stock = dram  Close Price = 1.300001
# Stock = emci  Close Price = 24.99
# Stock = bnso  Close Price = 1.01
# Stock = fcap  Close Price = 14.75
# Stock = bjri  Close Price = 9.62
# Stock = else  Close Price = 3.25
# Stock = actg  Close Price = 2.4
# Stock = fbms  Close Price = 16.0
# Stock = crtn  Close Price = 0.77
# Stock = cbak  Close Price = 2.6
# Stock = adrd  Close Price = 16.549999
# Stock = cers  Close Price = 2.33
# Stock = aaww  Close Price = 23.0
# Stock = dynt  Close Price = 0.4
# Stock = ebay  Close Price = 16.73
# Stock = ehth  Close Price = 11.62
# Stock = cern  Close Price = 34.98
# Stock = dspg  Close Price = 5.29
# Stock = ebtc  Close Price = 10.61
# Stock = flxs  Close Price = 9.75
# Stock = chnr  Close Price = 8.5
# Stock = belfb  Close Price = 18.950001
# Stock = atro  Close Price = 11.550017
# Stock = clbs  Close Price = 0.96
# Stock = dswl  Close Price = 3.02
# Stock = crnt  Close Price = 5.07
# Stock = clrb  Close Price = 0.4
# Stock = ctsh  Close Price = 17.360001
# Stock = bldr  Close Price = 3.77
# Stock = cmct  Close Price = 4.95
# Stock = ancx  Close Price = 5.0
# Stock = chdn  Close Price = 33.639999
# Stock = cac  Close Price = 27.0
# Stock = cutr  Close Price = 9.4
# Stock = bdge  Close Price = 18.959999
# Stock = cznc  Close Price = 25.0
# Stock = bdsi  Close Price = 2.17
# Stock = brkr  Close Price = 9.31
# Stock = carv  Close Price = 5.250263
# Stock = epay  Close Price = 7.9
# Stock = arii  Close Price = 8.73
# Stock = cnxn  Close Price = 5.91
# Stock = csgs  Close Price = 14.0
# Stock = arci  Close Price = 2.94
# Stock = ea  Close Price = 27.99
# Stock = cacc  Close Price = 16.77
# Stock = algn  Close Price = 6.77
# Stock = crvl  Close Price = 23.969999
# Stock = aplp  Close Price = 10.98
# Stock = ffiv  Close Price = 20.5
# Stock = etfc  Close Price = 2.23
# Stock = cspi  Close Price = 3.52
# Stock = cald  Close Price = 3.54
# Stock = aaon  Close Price = 16.130003
# Stock = diod  Close Price = 10.0
# Stock = abco  Close Price = 27.559999
# Stock = cthr  Close Price = 0.33
# Stock = atvi  Close Price = 11.56
# Stock = bcpc  Close Price = 23.140005
# Stock = bwld  Close Price = 33.919998
# Stock = chy  Close Price = 7.55
# Stock = cown  Close Price = 5.18
# Stock = akrx  Close Price = 3.25
# Stock = amag  Close Price = 35.450001
# Stock = cwst  Close Price = 7.86
# Stock = cbfv  Close Price = 14.25
# Stock = bebe  Close Price = 7.01
# Stock = artx  Close Price = 0.75
# Stock = alco  Close Price = 38.459999
# Stock = amat  Close Price = 12.7
# Stock = avhi  Close Price = 31.370001
# Stock = clro  Close Price = 4.18
# Stock = bwina  Close Price = 16.99
# Stock = eei  Close Price = 8.89
# Stock = flir  Close Price = 27.9
# Stock = cmtl  Close Price = 43.98
# Stock = csiq  Close Price = 12.69
# Stock = acta  Close Price = 6.02
# Stock = blfs  Close Price = 0.040001
# Stock = brcd  Close Price = 3.68
# Stock = cfbk  Close Price = 3.05
# Stock = cui  Close Price = 0.139986
# Stock = ctrn  Close Price = 12.35
# Stock = amtd  Close Price = 13.12
# Stock = asml  Close Price = 14.78
# Stock = apog  Close Price = 10.32
# Stock = eric  Close Price = 6.54
# Stock = efsc  Close Price = 15.58
# Stock = caty  Close Price = 19.030001
# Stock = acor  Close Price = 16.41
# Stock = chmg  Close Price = 20.799999
# Stock = biib  Close Price = 42.779999
# Stock = amwd  Close Price = 18.02
# Stock = asna  Close Price = 11.01
# Stock = cvly  Close Price = 11.64994
# Stock = cvbf  Close Price = 11.64
# Stock = eltk  Close Price = 0.97
# Stock = astc  Close Price = 0.34
# Stock = cpst  Close Price = 1.2
# Stock = fisv  Close Price = 35.990002
# Stock = amrn  Close Price = 0.9
# Stock = club  Close Price = 4.0
# Stock = chi  Close Price = 6.34
# Stock = capr  Close Price = 2.25
# Stock = drys  Close Price = 17.839994
# Stock = finl  Close Price = 6.95
# Stock = ffin  Close Price = 47.059979
# Stock = exls  Close Price = 5.48
# Stock = cvcy  Close Price = 7.46
# Stock = celg  Close Price = 54.52
# Stock = ccoi  Close Price = 4.88
# Stock = cigi  Close Price = 11.639999
# Stock = biol  Close Price = 1.449994
# Stock = achc  Close Price = 2.0
# Stock = fbss  Close Price = 12.5
# Stock = achn  Close Price = 1.55
# Stock = amot  Close Price = 4.21
# Stock = cbio  Close Price = 5.26
# Stock = evol  Close Price = 1.17
# Stock = ffkt  Close Price = 26.530001
# Stock = fbnc  Close Price = 14.51
# Stock = fll  Close Price = 1.2
# Stock = cyrn  Close Price = 1.55
# Stock = crws  Close Price = 2.75
# Stock = falc  Close Price = 4.16
# Stock = dnbf  Close Price = 11.25
# Stock = cbli  Close Price = 2.95
# Stock = fast  Close Price = 37.220001
# Stock = egan  Close Price = 0.45
# Stock = dysl  Close Price = 1.25
# Stock = fcco  Close Price = 9.1
# Stock = avnw  Close Price = 6.119998
# Stock = airt  Close Price = 7.16
# Stock = expo  Close Price = 27.16
# Stock = ctas  Close Price = 21.73
# Stock = cuba  Close Price = 3.64
# Stock = fisi  Close Price = 14.44
# Stock = cvgw  Close Price = 12.15
# Stock = cprx  Close Price = 2.2
# Stock = alot  Close Price = 6.0
# Stock = czfc  Close Price = 6.42
# Stock = aemd  Close Price = 0.32
# Stock = dzsi  Close Price = 0.12
# Stock = bont  Close Price = 2.12
# Stock = bosc  Close Price = 0.78
# Stock = ceco  Close Price = 15.45
# Stock = apri  Close Price = 0.11
# Stock = cizn  Close Price = 16.5
# Stock = acfc  Close Price = 6.59
# Stock = chco  Close Price = 39.709999
# Stock = crzo  Close Price = 17.24
# Stock = ecol  Close Price = 23.530001
# Stock = chfc  Close Price = 28.0
# Stock = ffbc  Close Price = 13.01
# Stock = asur  Close Price = 0.21
# Stock = bksc  Close Price = 11.039996
# Stock = arlz  Close Price = 8.75
# Stock = faro  Close Price = 17.4
# Stock = acgl  Close Price = 57.429989
# Stock = aey  Close Price = 1.95
# Stock = adre  Close Price = 26.139999
# Stock = ccrn  Close Price = 12.14
# Stock = aray  Close Price = 6.0
# Stock = aimc  Close Price = 9.82
# Stock = ewbc  Close Price = 13.59
# Stock = bbox  Close Price = 26.91
# Stock = dgii  Close Price = 7.92
# Stock = cytk  Close Price = 2.170043
# Stock = boom  Close Price = 17.059999
# Stock = casi  Close Price = 0.280003
# Stock = camp  Close Price = 0.93
# Stock = eght  Close Price = 0.68
# Stock = farm  Close Price = 19.08
# Stock = adru  Close Price = 16.870001
# Stock = dorm  Close Price = 12.05
# Stock = dgas  Close Price = 18.01
# Stock = czwi  Close Price = 6.4
# Stock = esxb  Close Price = 3.35
# Stock = cart  Close Price = 8.51
# Stock = core  Close Price = 20.530001
# Stock = csq  Close Price = 5.01
# Stock = bcbp  Close Price = 12.99
# Stock = asfi  Close Price = 3.6
# Stock = basi  Close Price = 4.0
# Stock = bset  Close Price = 6.52
# Stock = dwaq  Close Price = 34.25
# Stock = agys  Close Price = 6.67
# Stock = cvv  Close Price = 2.59
# Stock = bokf  Close Price = 40.290001
# Stock = cool  Close Price = 0.760015
# Stock = cfcb  Close Price = 13.188681
# Stock = ctg  Close Price = 5.85
# Stock = cemi  Close Price = 0.17
# Stock = ainv  Close Price = 9.98
# Stock = brid  Close Price = 5.56
# Stock = fele  Close Price = 39.98
# Stock = amkr  Close Price = 4.27
# Stock = cidm  Close Price = 1.35
# Stock = clfd  Close Price = 0.95
# Stock = crus  Close Price = 4.37
# Stock = dxpe  Close Price = 16.57
# Stock = bmrc  Close Price = 27.01
# Stock = cgo  Close Price = 7.42
# Stock = ctbi  Close Price = 28.969998
# Stock = bios  Close Price = 2.37
# Stock = cris  Close Price = 0.93
# Stock = cdti  Close Price = 3.180063
# Stock = dwsn  Close Price = 3.840011
# Stock = egbn  Close Price = 6.800002
# Stock = cass  Close Price = 30.790001
# Stock = emms  Close Price = 0.94
# Stock = calm  Close Price = 24.32
# Stock = ctxs  Close Price = 20.199999
# Stock = edgw  Close Price = 1.98
# Stock = anss  Close Price = 28.610001
# Stock = esnd  Close Price = 37.09
# Stock = afsi  Close Price = 8.08
# Stock = casy  Close Price = 24.75
# Stock = esio  Close Price = 10.48
# Stock = aezs  Close Price = 0.460001
# Stock = banr  Close Price = 11.290225
# Stock = bsrr  Close Price = 16.620001
# Stock = eqfn  Close Price = 8.0
# Stock = amzn  Close Price = 56.25
# Stock = camt  Close Price = 0.76
# Stock = cpss  Close Price = 1.32
# Stock = chkp  Close Price = 17.82
# Stock = dish  Close Price = 13.71
# Stock = cvti  Close Price = 2.01
# Stock = arql  Close Price = 2.9
# Stock = ahpi  Close Price = 4.45
# Stock = csx  Close Price = 43.309999
# Stock = amsf  Close Price = 14.97
# Stock = cpsh  Close Price = 1.95
# Stock = bmra  Close Price = 0.66
# Stock = aeis  Close Price = 10.0
# Stock = cmcsa  Close Price = 15.36
# Stock = afam  Close Price = 35.080002
# Stock = aobc  Close Price = 2.21
# Stock = coke  Close Price = 37.959999
# Stock = exel  Close Price = 4.01
# Stock = alqa  Close Price = 0.200025
# Stock = agen  Close Price = 0.610012
# Stock = ceva  Close Price = 7.13
# Stock = bncn  Close Price = 8.99
# Stock = cwco  Close Price = 12.81
# Stock = asrv  Close Price = 1.59
# Stock = akam  Close Price = 14.12
# Stock = airm  Close Price = 23.439991
# Stock = chci  Close Price = 0.34
# Stock = bpopn  Close Price = 20.129999
# ValueErrorTraceback (most recent call last)
# <ipython-input-7-cb348be0a1ad> in <module>()
#       5
#       6     for stock, price in stocks_data.items():
# ----> 7         i = price['date'].index(d)
#       8         print('Stock =',stock,' Close Price =',price['close'][i] )
#       9         #print(i)
#
# ValueError: datetime.datetime(2008, 10, 10, 0, 0) is not in list

# %% [markdown]
# <b> Finding the most profitable stock <b>

# %%
stock_performance = []
for s,prices in stocks_data.items():
    price_difference = prices['close'][-1] - prices['close'][0]
    pct_difference = price_difference / prices['close'][0]
    stock_performance.append((s,pct_difference))


most_profitable = max(stock_performance,key=lambda item:item[1])
print('The most profitable stock is:', most_profitable[0])
print('Percentage Growth =',most_profitable[1])
# Out:
# The most profitable stock is: admp
# Percentage Growth = 74.83838922594839

# %%
print('done')
# Out:
# done
